# %%
from langchain_community.llms import Ollama

llm = Ollama(model="mistral")

print(llm.invoke("tell me a joke"))
# Out:
# C:\Users\dahisesantos\AppData\Local\Temp\ipykernel_14400\2728659114.py:3: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="mistral")
#  Sure, here's a classic one for you:
#
# Why don't scientists trust atoms?
#
# Because they make up everything!
#
# I hope that made you smile!

# %%
print(llm.invoke([{"content": "What is the capital of France?", "type":"user"}]))
# Out:
#  The capital of France is Paris.

# %%
from langchain_community.chat_models import ChatOllama

chat_llm = ChatOllama(model="mistral")
print(chat_llm.invoke([{"role": "user", "content": "What is the capital of France?"}]))
# Out:
# C:\Users\dahisesantos\AppData\Local\Temp\ipykernel_14400\3574328151.py:3: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   chat_llm = ChatOllama(model="mistral")
# content=' The capital of France is Paris.' additional_kwargs={} response_metadata={'model': 'mistral', 'created_at': '2025-08-19T13:07:55.8445966Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 1904092500, 'load_duration': 15917000, 'prompt_eval_count': 11, 'prompt_eval_duration': 554374500, 'eval_count': 8, 'eval_duration': 1332176800} id='run--f8c712d0-531e-470f-9585-2b169236b0de-0'
